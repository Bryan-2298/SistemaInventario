# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryan-2298/SistemaInventario/blob/master/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Integrantes: **
#
# Vargas Loza Luis Enrique
#
# Medellin Magdaleno Jessica
#
#
# **Ejercicio 1** :
#
#  Donde realizamos el repositorio en Github y se agrego al profesor y los compañeros colaboradores.
#
#  **Ejercicio 2**:
#
#  Se realizo el conteo de los tokens donde tenian que ser 14 tokens en total donde concluimos que si, cumplia el objetivo.

# %%
# !python lexer.py ejemplos/imp_base.imp
# !python -m unittest -v
# Out:
# TIPO       LEXEMA           POSICIÓN
# LOC        'X'              1:1
# ASSIGN     ':='             1:3
# NUM        '0'              1:6
# SEMI       ';'              1:7
# WHILE      'while'          2:1
# LOC        'X'              2:7
# LE         '<='             2:9
# NUM        '3'              2:12
# DO         'do'             2:14
# LOC        'X'              2:17
# ASSIGN     ':='             2:19
# LOC        'X'              2:22
# PLUS       '+'              2:24
# NUM        '1'              2:26
# test_asignacion_aritmetica (test.test_lexer_base.PruebasLexerBase.test_asignacion_aritmetica) ... ok
# test_caracter_no_reconocido (test.test_lexer_base.PruebasLexerBase.test_caracter_no_reconocido) ... ok
# test_operadores_booleanos (test.test_lexer_base.PruebasLexerBase.test_operadores_booleanos) ... ok
# test_palabra_reservada_y_localidad (test.test_lexer_base.PruebasLexerBase.test_palabra_reservada_y_localidad) ... ok
# ...

# %% [markdown]
# **Ejercicio 3**:
# Se realizo los cambios en el COMMENT

# %%
# !python -m unittest -v
# Out:
# test_asignacion_aritmetica (test.test_lexer_base.PruebasLexerBase.test_asignacion_aritmetica) ... ok
# test_caracter_no_reconocido (test.test_lexer_base.PruebasLexerBase.test_caracter_no_reconocido) ... ok
# test_operadores_booleanos (test.test_lexer_base.PruebasLexerBase.test_operadores_booleanos) ... ok
# test_palabra_reservada_y_localidad (test.test_lexer_base.PruebasLexerBase.test_palabra_reservada_y_localidad) ... ok
# test_posicion_en_segunda_linea (test.test_lexer_base.PruebasLexerBase.test_posicion_en_segunda_linea) ... ok
# test_comentario_se_ignora (test.test_lexer_imp_mas_mas.PruebasLexerImpMasMas.test_comentario_se_ignora) ... ok
# test_identificador_con_guion_bajo (test.test_lexer_imp_mas_mas.PruebasLexerImpMasMas.test_identificador_con_guion_bajo) ... ok
# test_incremento_y_decremento_son_tokens_completos (test.test_lexer_imp_mas_mas.PruebasLexerImpMasMas.test_incremento_y_decremento_son_tokens_completos) ... skipped 'Retira este decorador después de agregar INC y DEC'
# ...
